# %%
## Data ---> Seperate (Categorical, Numerical)
# Categorical Data ---> Missing values fill ---> Encode
# Numerical Data ---> Missing values fill ---> Standardize
# Apply ---> ML Model
# Calculate Model's Preformance

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\vedan\\OneDrive\\Documents\\Regex\\Python\\ML\\CSV Files\\covid_toy.csv')

# %%
df.head()
# Out:
#       age        gender    fever       cough            city has_covid
# 0      60          Male      103        Mild         Kolkata        No
# 1      27          Male      100        Mild           Delhi       Yes
# 2  42\n31  Male\nFemale  101\n98  Mild\nMild  Delhi\nKolkata    No\nNo
# 3      65        Female      101        Mild          Mumbai        No
# 4      84        Female      NaN        Mild       Bangalore       Yes

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
x = df.drop(columns=['has_covid'])
y= df['has_covid']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=56)

# %%
categorical_features = ['gender', 'city']
numerical_features = ['age', 'fever']

df[numerical_features] = df[numerical_features].apply(
    pd.to_numeric, errors='coerce'
)
df[numerical_features] = df[numerical_features].fillna(df[numerical_features].mean())

# %%
## Now we will create our transformers
numeric_transformers = Pipeline(steps= [
    ('imputer',SimpleImputer(strategy= 'mean')),
    ('scale', StandardScaler()) 
])

categoric_transformers = Pipeline(steps = [
    ('imputer', SimpleImputer(strategy= 'most_frequent')),
    ('encode', OneHotEncoder(handle_unknown= 'ignore'))
])

# %%
## Combine Transformers
preprocessor = ColumnTransformer(transformers= [
    ('num', numeric_transformers, numerical_features),
    ('cat', categoric_transformers, categorical_features)
])

# %%
## Creating Pipeline for models
rf = Pipeline(steps= [
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier())
])

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
numerical_features = ['age', 'fever']

df[numerical_features] = df[numerical_features].replace(
    r'[^0-9.]', '', regex=True
)

# %%
df[numerical_features] = df[numerical_features].apply(
    pd.to_numeric, errors='coerce'
)

# %%
df[numerical_features] = df[numerical_features].fillna(
    df[numerical_features].mean()
)

# %%
df[numerical_features].dtypes
# Out:
# age      float64
# fever    float64
# dtype: object

# %%
df.head(11)
# Out:
#           age          gender       fever           cough               city  \
# 0   60.000000            Male  103.000000            Mild            Kolkata
# 1   27.000000            Male  100.000000            Mild              Delhi
# 2   40.653846    Male\nFemale  100.942308      Mild\nMild     Delhi\nKolkata
# 3   65.000000          Female  101.000000            Mild             Mumbai
# 4   84.000000          Female  100.942308            Mild          Bangalore
# 5   40.653846    Male\nFemale  101.000000  Strong\nStrong  Bangalore\nMumbai
# 6   19.000000          Female  100.000000          Strong          Bangalore
# 7   64.000000          Female  101.000000            Mild              Delhi
# 8   40.653846  Female\nFemale   98.000000      Mild\nMild      Delhi\nMumbai
# 9   25.000000          Female   99.000000          Strong            Kolkata
# 10  64.000000            Male  102.000000            Mild          Bangalore
#
#    has_covid
# 0         No
# 1        Yes
# 2     No\nNo
# 3         No
# 4        Yes
# 5    No\nYes
# 6         No
# 7         No
# 8    No\nYes
# 9         No
# 10       Yes

# %%
df[numerical_features].head(20)
# Out:
#           age       fever
# 0   60.000000  103.000000
# 1   27.000000  100.000000
# 2   40.653846  100.942308
# 3   65.000000  101.000000
# 4   84.000000  100.942308
# 5   40.653846  101.000000
# 6   19.000000  100.000000
# 7   64.000000  101.000000
# 8   40.653846   98.000000
# 9   25.000000   99.000000
# 10  64.000000  102.000000
# 11  40.653846  100.942308
# 12  69.000000  103.000000
# 13  40.000000   98.000000
# 14  40.653846   98.000000
# 15  12.000000   98.000000
# 16  73.000000   98.000000
# 17  40.653846  100.942308
# 18  13.000000  100.000000
# 19  23.000000  100.942308

# %%
df[numerical_features].applymap(type)
# Out:
# C:\Users\vedan\AppData\Local\Temp\ipykernel_38324\3211527601.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[numerical_features].applymap(type)
#                 age            fever
# 0   <class 'float'>  <class 'float'>
# 1   <class 'float'>  <class 'float'>
# 2   <class 'float'>  <class 'float'>
# 3   <class 'float'>  <class 'float'>
# 4   <class 'float'>  <class 'float'>
# ..              ...              ...
# 71  <class 'float'>  <class 'float'>
# 72  <class 'float'>  <class 'float'>
# 73  <class 'float'>  <class 'float'>
# 74  <class 'float'>  <class 'float'>
# 75  <class 'float'>  <class 'float'>
#
# [76 rows x 2 columns]

# %%
for col in numerical_features:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace(r"\s+", "", regex=True)  # remove \n, spaces
    )
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
df[numerical_features].dtypes
df[numerical_features].isna().sum()
# Out:
# age      0
# fever    0
# dtype: int64
